# %%
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 70.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="H6cJ3vcqCcDOMikwj7Wv")
project = rf.workspace("dana-vmvt5").project("fukuro_goru")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to fukuro_goru-1 in yolo26:: 100%|██████████| 1390/1390 [00:00<00:00, 7199.80it/s]

# %%
# !pip install ultralytics --upgrade

# %%
print(f"Dataset location: {dataset.location}")
# Out:
# Dataset location: /content/fukuro_goru-1

# %%
# !pip show ultralytics
# Out:
# Name: ultralytics
# Version: 8.4.8
# Summary: Ultralytics YOLO 🚀 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page: https://ultralytics.com
# Author:
# Author-email: Glenn Jocher <glenn.jocher@ultralytics.com>, Jing Qiu <jing.qiu@ultralytics.com>
# License: AGPL-3.0
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: matplotlib, numpy, opencv-python, pillow, polars, psutil, pyyaml, requests, scipy, torch, torchvision, ultralytics-thop
# Required-by:

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

# Muat model dasar
model = YOLO('/content/drive/MyDrive/FUKURO/GAWANG - YOLO/yolo26n-seg.pt')

# Tentukan jalur lengkap untuk folder penyimpanan hasil
output_dir = '/content/drive/MyDrive/FUKURO/GAWANG - YOLO/Front'

# Path ke file data.yaml (dari langkah sebelumnya)
# Pastikan Anda sudah menjalankan langkah download dataset roboflow sebelumnya
yaml_path = f"{dataset.location}/data.yaml"

# Mulai pelatihan dengan menentukan lokasi project dan nama run
results = model.train(
    data=yaml_path,
    epochs=300,
    imgsz=640,
    batch=32,
    project=output_dir, # <-- Ini yang menentukan folder utama
    name='training_run_1', # <-- Hasil spesifik akan masuk ke sini
    device=0
)
# Out:
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# ...

# %%
from ultralytics import YOLO

# Muat model dasar
model = YOLO('/content/drive/MyDrive/FUKURO/GAWANG - YOLO/yolo26n-seg.pt')

# Tentukan jalur lengkap untuk folder penyimpanan hasil
output_dir = '/content/drive/MyDrive/FUKURO/GAWANG - YOLO/Front'

# Path ke file data.yaml (dari langkah sebelumnya)
# Pastikan Anda sudah menjalankan langkah download dataset roboflow sebelumnya
yaml_path = f"{dataset.location}/data.yaml"

# Mulai pelatihan dengan menentukan lokasi project dan nama run
results = model.train(
    data=yaml_path,
    epochs=400,
    imgsz=640,
    batch=16,
    project=output_dir, # <-- Ini yang menentukan folder utama
    name='training_run_2_16btch', # <-- Hasil spesifik akan masuk ke sini
    device=0
)
# Out:
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# ...
